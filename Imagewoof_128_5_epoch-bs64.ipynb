# %% [markdown]
# ## Baseline: Adam + OneCycle

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 3e-3 --gpu 2 \
                --opt adam
# Out:
# /home/u/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.159516</td>
#       <td>2.506504</td>
#       <td>0.228000</td>
#       <td>0.726000</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.926315</td>
#       <td>1.927992</td>
#       <td>0.318000</td>
#       <td>0.846000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.703951</td>
#       <td>1.818840</td>
#       <td>0.462000</td>
#       <td>0.906000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.502392</td>
#       <td>1.412812</td>
#       <td>0.590000</td>
#       <td>0.946000</td>
#       <td>00:17</td>
#     </tr>
# ...

# %% [markdown]
# ## RangerLars (RAdam + LARS + Lookahead) + flat_and_anneal

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 3 \
                --opt over9000 --sched_type flat_and_anneal --ann_start 0.5
# Out:
# /home/u/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.216540</td>
#       <td>2.295112</td>
#       <td>0.218000</td>
#       <td>0.754000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.959835</td>
#       <td>2.096485</td>
#       <td>0.272000</td>
#       <td>0.812000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.765769</td>
#       <td>1.724890</td>
#       <td>0.470000</td>
#       <td>0.910000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.541118</td>
#       <td>1.445299</td>
#       <td>0.554000</td>
#       <td>0.952000</td>
#       <td>00:24</td>
#     </tr>
# ...

# %% [markdown]
# ## Ralamb (RAdam + LARS)

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 3e-3 --gpu 3 \
                --opt ralamb --sched_type flat_and_anneal --ann_start 0.5
# Out:
# /home/u/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.130370</td>
#       <td>2.649916</td>
#       <td>0.172000</td>
#       <td>0.628000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.892075</td>
#       <td>1.855750</td>
#       <td>0.366000</td>
#       <td>0.870000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.704597</td>
#       <td>1.856849</td>
#       <td>0.400000</td>
#       <td>0.860000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.500829</td>
#       <td>1.437564</td>
#       <td>0.604000</td>
#       <td>0.942000</td>
#       <td>00:24</td>
#     </tr>
# ...

# %% [markdown]
# ## Ranger (RAdam + Lookahead)

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 2 \
                --opt ranger --sched_type flat_and_anneal --ann_start 0.5
# Out:
# /home/u/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.177389</td>
#       <td>2.522537</td>
#       <td>0.260000</td>
#       <td>0.742000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.965153</td>
#       <td>2.023272</td>
#       <td>0.332000</td>
#       <td>0.832000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.820642</td>
#       <td>1.734957</td>
#       <td>0.452000</td>
#       <td>0.896000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.602269</td>
#       <td>1.639607</td>
#       <td>0.492000</td>
#       <td>0.916000</td>
#       <td>00:17</td>
#     </tr>
# ...

# %% [markdown]
# ## Novograd + bigger lr

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 3e-2 --gpu 2 \
                --opt novograd --sched_type flat_and_anneal --ann_start 0.5
# Out:
# /home/u/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.128035</td>
#       <td>2.124353</td>
#       <td>0.274000</td>
#       <td>0.774000</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.923596</td>
#       <td>2.069598</td>
#       <td>0.338000</td>
#       <td>0.794000</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.783634</td>
#       <td>1.882008</td>
#       <td>0.356000</td>
#       <td>0.864000</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.608060</td>
#       <td>1.725030</td>
#       <td>0.420000</td>
#       <td>0.916000</td>
#       <td>00:19</td>
#     </tr>
# ...

# %% [markdown]
# ## Radam

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 2 \
                --opt radam --sched_type flat_and_anneal --ann_start 0.5
# Out:
# /home/u/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.187119</td>
#       <td>6.683732</td>
#       <td>0.184000</td>
#       <td>0.636000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.976174</td>
#       <td>2.130867</td>
#       <td>0.296000</td>
#       <td>0.802000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.824010</td>
#       <td>2.182111</td>
#       <td>0.222000</td>
#       <td>0.736000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.660884</td>
#       <td>1.743929</td>
#       <td>0.460000</td>
#       <td>0.890000</td>
#       <td>00:18</td>
#     </tr>
# ...

# %% [markdown]
# ## Lookahead

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 3e-3 --gpu 2 \
                --opt lookahead
# Out:
# /home/u/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.122257</td>
#       <td>2.300046</td>
#       <td>0.226000</td>
#       <td>0.776000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.897391</td>
#       <td>3.306921</td>
#       <td>0.288000</td>
#       <td>0.744000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.732657</td>
#       <td>1.651140</td>
#       <td>0.500000</td>
#       <td>0.902000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.511979</td>
#       <td>1.460277</td>
#       <td>0.576000</td>
#       <td>0.942000</td>
#       <td>00:17</td>
#     </tr>
# ...

# %% [markdown]
# ## Lamb

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 2 \
                --opt lamb
# Out:
# /home/u/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.133302</td>
#       <td>2.554022</td>
#       <td>0.226000</td>
#       <td>0.642000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.995912</td>
#       <td>2.034954</td>
#       <td>0.348000</td>
#       <td>0.808000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.809772</td>
#       <td>2.001213</td>
#       <td>0.360000</td>
#       <td>0.828000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.635187</td>
#       <td>1.643392</td>
#       <td>0.502000</td>
#       <td>0.898000</td>
#       <td>00:24</td>
#     </tr>
# ...

# %% [markdown]
# ## DiffGrad

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 2 \
                --opt diffgrad
# Out:
# To use this log_lamb_rs, please run 'pip install tensorboardx'. Also you must have Tensorboard running to see results
# /home/u/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.167449</td>
#       <td>3.096631</td>
#       <td>0.192000</td>
#       <td>0.662000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.050520</td>
#       <td>2.079067</td>
#       <td>0.294000</td>
#       <td>0.808000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.775661</td>
#       <td>1.805413</td>
#       <td>0.394000</td>
#       <td>0.872000</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
# ...

# %% [markdown]
# ## AdaMod

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 2 \
                --opt adamod
# Out:
# /home/u/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.116744</td>
#       <td>2.528644</td>
#       <td>0.252000</td>
#       <td>0.706000</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.008717</td>
#       <td>1.932243</td>
#       <td>0.354000</td>
#       <td>0.830000</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.863138</td>
#       <td>2.077132</td>
#       <td>0.286000</td>
#       <td>0.764000</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.655552</td>
#       <td>1.682798</td>
#       <td>0.432000</td>
#       <td>0.902000</td>
#       <td>00:20</td>
#     </tr>
# ...
