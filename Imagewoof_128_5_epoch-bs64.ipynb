# %% [markdown]
# ## Baseline: Adam + OneCycle

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 3e-3 --gpu 0 --opt adam
# Out:
# To use this log_lamb_rs, please run 'pip install tensorboardx'. Also you must have Tensorboard running to see results
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ...
# {'avg_val_loss': 9.34090518951416, 'avg_acc': 0.0}
# ...
# {'avg_val_loss': 2.988534688949585, 'avg_acc': 0.2834475636482239}
# ...
# {'avg_val_loss': 2.7736756801605225, 'avg_acc': 0.31543347239494324}
# ...
# {'avg_val_loss': 2.483459949493408, 'avg_acc': 0.4201713502407074}
# ...
# {'avg_val_loss': 2.315356969833374, 'avg_acc': 0.492933452129364}
# ...
# {'avg_val_loss': 2.1187615394592285, 'avg_acc': 0.5760987401008606}
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# ...

# %% [markdown]
# ## RangerLars (RAdam + LARS + Lookahead) + flat_and_anneal

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 1e-2 --gpu 0 \
                --opt rangerlars --sched_type flat_and_anneal --ann_start 0.5
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
# /home/u/.anaconda/envs/over9000/lib/python3.8/site-packages/torch/optim/lr_scheduler.py:118: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# /home/u/.anaconda/envs/over9000/lib/python3.8/site-packages/torch/optim/lr_scheduler.py:231: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
#
# ...

# %% [markdown]
# ## Ralamb (RAdam + LARS)

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 3e-3 --gpu 0 \
                --opt ralamb --sched_type flat_and_anneal --ann_start 0.5
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ...
# {'avg_val_loss': 6.937027454376221, 'avg_acc': 0.0}
# ...
# {'avg_val_loss': 2.7281248569488525, 'avg_acc': 0.32603830099105835}
# ...
# {'avg_val_loss': 2.588507652282715, 'avg_acc': 0.38842740654945374}
# ...
# {'avg_val_loss': 2.5723466873168945, 'avg_acc': 0.4157862663269043}
# ...
# {'avg_val_loss': 2.3271656036376953, 'avg_acc': 0.48866933584213257}
# ...
# {'avg_val_loss': 2.2894628047943115, 'avg_acc': 0.5021975636482239}
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ...

# %% [markdown]
# ## Ranger (RAdam + Lookahead)

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 1e-2 --gpu 0 \
                --opt ranger --sched_type flat_and_anneal --ann_start 0.5
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ...
# {'avg_val_loss': 7.226234436035156, 'avg_acc': 0.0}
# ...
# {'avg_val_loss': 2.785987615585327, 'avg_acc': 0.313991904258728}
# ...
# {'avg_val_loss': 2.6084229946136475, 'avg_acc': 0.38537296652793884}
# ...
# {'avg_val_loss': 2.588137626647949, 'avg_acc': 0.3930443227291107}
# ...
# {'avg_val_loss': 2.2855429649353027, 'avg_acc': 0.5157257914543152}
# ...
# {'avg_val_loss': 2.2722585201263428, 'avg_acc': 0.519395112991333}
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ...

# %% [markdown]
# ## Novograd + bigger lr

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 3e-2 --gpu 0 \
                --opt novograd --sched_type flat_and_anneal --ann_start 0.5
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ...
# {'avg_val_loss': 9.076925277709961, 'avg_acc': 0.0}
# ...
# {'avg_val_loss': 2.8086562156677246, 'avg_acc': 0.3006955683231354}
# ...
# {'avg_val_loss': 2.637190103530884, 'avg_acc': 0.36363908648490906}
# ...
# {'avg_val_loss': 2.6469552516937256, 'avg_acc': 0.379304438829422}
# ...
# {'avg_val_loss': 2.3006513118743896, 'avg_acc': 0.5072681307792664}
# ...
# {'avg_val_loss': 2.2797327041625977, 'avg_acc': 0.5193648934364319}
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ...

# %% [markdown]
# ## Radam

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 1e-2 --gpu 0 \
                --opt radam --sched_type flat_and_anneal --ann_start 0.5
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ...
# {'avg_val_loss': 7.058874130249023, 'avg_acc': 0.0}
# ...
# {'avg_val_loss': 2.7931361198425293, 'avg_acc': 0.2860282063484192}
# ...
# {'avg_val_loss': 2.6107983589172363, 'avg_acc': 0.3877822458744049}
# ...
# {'avg_val_loss': 2.537165880203247, 'avg_acc': 0.42300400137901306}
# ...
# {'avg_val_loss': 2.2828080654144287, 'avg_acc': 0.507016122341156}
# ...
# {'avg_val_loss': 2.2631239891052246, 'avg_acc': 0.5151914954185486}
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ...

# %% [markdown]
# ## Lookahead

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 3e-3 --gpu 0 \
                --opt lookahead
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ...
# {'avg_val_loss': 5.846227645874023, 'avg_acc': 0.0}
# ...
# {'avg_val_loss': 3.497986078262329, 'avg_acc': 0.22065523266792297}
# ...
# {'avg_val_loss': 2.7298474311828613, 'avg_acc': 0.306179404258728}
# ...
# {'avg_val_loss': 2.536541223526001, 'avg_acc': 0.3938608765602112}
# ...
# {'avg_val_loss': 2.373534679412842, 'avg_acc': 0.4840019941329956}
# ...
# {'avg_val_loss': 2.168621301651001, 'avg_acc': 0.5496370792388916}
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ...

# %% [markdown]
# ## Lamb

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 1e-2 --gpu 0 \
                --opt lamb
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ...
# {'avg_val_loss': 8.850435256958008, 'avg_acc': 0.0}
# ...
# {'avg_val_loss': 3.0008461475372314, 'avg_acc': 0.2432257980108261}
# ...
# {'avg_val_loss': 2.76674222946167, 'avg_acc': 0.3207056522369385}
# ...
# {'avg_val_loss': 2.624650478363037, 'avg_acc': 0.3881451487541199}
# ...
# {'avg_val_loss': 2.311373233795166, 'avg_acc': 0.49567538499832153}
# ...
# {'avg_val_loss': 2.1670279502868652, 'avg_acc': 0.5478426814079285}
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ...

# %% [markdown]
# ## DiffGrad

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 1e-2 --gpu 0 \
                --opt diffgrad
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ...
# {'avg_val_loss': 6.977771759033203, 'avg_acc': 0.0}
# ...
# {'avg_val_loss': 3.238225221633911, 'avg_acc': 0.19424395263195038}
# ...
# {'avg_val_loss': 2.7442269325256348, 'avg_acc': 0.3153427541255951}
# ...
# {'avg_val_loss': 2.680560350418091, 'avg_acc': 0.3626108765602112}
# ...
# {'avg_val_loss': 2.2948410511016846, 'avg_acc': 0.4939616918563843}
# ...
# {'avg_val_loss': 2.171316385269165, 'avg_acc': 0.5489919185638428}
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ...

# %% [markdown]
# ## AdaMod

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 1e-2 --gpu 0 \
                --opt adamod
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ...
# {'avg_val_loss': 11.633865356445312, 'avg_acc': 0.0}
# ...
# {'avg_val_loss': 3.5452568531036377, 'avg_acc': 0.2163810431957245}
# ...
# {'avg_val_loss': 2.7641732692718506, 'avg_acc': 0.3247177302837372}
# ...
# {'avg_val_loss': 2.732297658920288, 'avg_acc': 0.3558870851993561}
# ...
# {'avg_val_loss': 2.329982042312622, 'avg_acc': 0.4677318334579468}
# ...
# {'avg_val_loss': 2.1691524982452393, 'avg_acc': 0.5502217411994934}
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ...

# %% [markdown]
# ## Madam

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 1e-2 --gpu 0 \
                --opt madam --sched_type flat_and_anneal --ann_start 0.5
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ...
# {'avg_val_loss': 9.964943885803223, 'avg_acc': 0.0}
# ...
# {'avg_val_loss': 2.8208963871002197, 'avg_acc': 0.2801915407180786}
# ...
# {'avg_val_loss': 2.6415646076202393, 'avg_acc': 0.37761086225509644}
# ...
# {'avg_val_loss': 2.473186492919922, 'avg_acc': 0.4324394762516022}
# ...
# {'avg_val_loss': 2.333167314529419, 'avg_acc': 0.4940221607685089}
# ...
# {'avg_val_loss': 2.313619613647461, 'avg_acc': 0.5043548345565796}
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ...

# %% [markdown]
# ## Apollo

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 3e-3 --gpu 0 \
                --opt apollo
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ...
# {'avg_val_loss': 10.230222702026367, 'avg_acc': 0.0}
# ...
# {'avg_val_loss': 2.9245309829711914, 'avg_acc': 0.2775000035762787}
# ...
# {'avg_val_loss': 2.7688825130462646, 'avg_acc': 0.31418344378471375}
# ...
# {'avg_val_loss': 2.577775478363037, 'avg_acc': 0.40060481429100037}
# ...
# {'avg_val_loss': 2.2723302841186523, 'avg_acc': 0.5146270394325256}
# ...
# {'avg_val_loss': 2.150902032852173, 'avg_acc': 0.5642237067222595}
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ...

# %% [markdown]
# ## AdaBelief

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 3e-3 --gpu 0 \
                --opt adabelief --eps 1e-16
# Out:
# To use this log_lamb_rs, please run 'pip install tensorboardx'. Also you must have Tensorboard running to see results
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2]
# Using native 16bit precision.
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ...
# {'avg_val_loss': 7.670018196105957, 'avg_acc': 0.0}
# ...
# {'avg_val_loss': 3.344857931137085, 'avg_acc': 0.2236088663339615}
# ...
# {'avg_val_loss': 4.096182823181152, 'avg_acc': 0.2062096744775772}
# ...
# {'avg_val_loss': 2.9672868251800537, 'avg_acc': 0.3234979808330536}
# ...
# {'avg_val_loss': 2.387486696243286, 'avg_acc': 0.480806440114975}
# ...
# {'avg_val_loss': 2.159132957458496, 'avg_acc': 0.561592698097229}
#
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# ...
