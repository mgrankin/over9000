# %% [markdown]
# ## Baseline: Adam + OneCycle

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 3e-3 --gpu 2,3 --opt adam
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25.6 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ---------------------------------------------------------
# 25.6 M    Trainable params
# 0         Non-trainable params
# 25.6 M    Total params
# 102.305   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# {'avg_val_loss': 9.415772438049316, 'avg_acc': 0.0}
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 3.4993324279785156, 'avg_acc': 0.20486973226070404}
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 2.8828542232513428, 'avg_acc': 0.30540478229522705}
# Validating: 0it [00:00, ?it/s]
# ...

# %% [markdown]
# ## RangerLars (RAdam + LARS + Lookahead) + flat_and_anneal

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 1e-2 --gpu 2,3 \
                --opt rangerlars --sched_type flat_and_anneal --ann_start 0.5
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# /home/u/.anaconda/envs/over9000/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:129: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# /home/u/.anaconda/envs/over9000/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:247: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
# ...

# %% [markdown]
# ## Ralamb (RAdam + LARS)

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 3e-3 --gpu 2,3 \
                --opt ralamb --sched_type flat_and_anneal --ann_start 0.5
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# /home/u/.anaconda/envs/over9000/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:129: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# /home/u/.anaconda/envs/over9000/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:247: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
# ...

# %% [markdown]
# ## Ranger (RAdam + Lookahead)

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 1e-2 --gpu 2,3 \
                --opt ranger --sched_type flat_and_anneal --ann_start 0.5
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25.6 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ---------------------------------------------------------
# 25.6 M    Trainable params
# 0         Non-trainable params
# 25.6 M    Total params
# 102.305   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# {'avg_val_loss': 7.768766403198242, 'avg_acc': 0.0}
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 3.25699520111084, 'avg_acc': 0.24954119324684143}
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 2.576317071914673, 'avg_acc': 0.3861468434333801}
# Validating: 0it [00:00, ?it/s]
# ...

# %% [markdown]
# ## Novograd + bigger lr

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 3e-2 --gpu 2,3 \
                --opt novograd --sched_type flat_and_anneal --ann_start 0.5
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25.6 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ---------------------------------------------------------
# 25.6 M    Trainable params
# 0         Non-trainable params
# 25.6 M    Total params
# 102.305   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# {'avg_val_loss': 10.054580688476562, 'avg_acc': 0.0}
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 3.0216753482818604, 'avg_acc': 0.24583204090595245}
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 2.965055227279663, 'avg_acc': 0.26842302083969116}
# Validating: 0it [00:00, ?it/s]
# ...

# %% [markdown]
# ## Radam

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 1e-2 --gpu 2,3 \
                --opt radam --sched_type flat_and_anneal --ann_start 0.5
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25.6 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ---------------------------------------------------------
# 25.6 M    Trainable params
# 0         Non-trainable params
# 25.6 M    Total params
# 102.305   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# {'avg_val_loss': 8.804363250732422, 'avg_acc': 0.0}
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 6.250090599060059, 'avg_acc': 0.14868950843811035}
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 2.9201197624206543, 'avg_acc': 0.20281481742858887}
# Validating: 0it [00:00, ?it/s]
# ...

# %% [markdown]
# ## Lookahead

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 3e-3 --gpu 2,3 \
                --opt lookahead
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25.6 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ---------------------------------------------------------
# 25.6 M    Trainable params
# 0         Non-trainable params
# 25.6 M    Total params
# 102.305   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# {'avg_val_loss': 7.168868064880371, 'avg_acc': 0.0}
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 3.43104887008667, 'avg_acc': 0.20688585937023163}
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 2.7336671352386475, 'avg_acc': 0.33775973320007324}
# {'avg_val_loss': 2.6081862449645996, 'avg_acc': 0.3909674882888794}
# ...

# %% [markdown]
# ## Lamb

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 1e-2 --gpu 2,3 \
                --opt lamb
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25.6 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ---------------------------------------------------------
# 25.6 M    Trainable params
# 0         Non-trainable params
# 25.6 M    Total params
# 102.305   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# {'avg_val_loss': 6.443014144897461, 'avg_acc': 0.0}
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 3.1925137042999268, 'avg_acc': 0.22010700404644012}
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 2.712921619415283, 'avg_acc': 0.3261928856372833}
# Validating: 0it [00:00, ?it/s]
# ...

# %% [markdown]
# ## DiffGrad

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 1e-2 --gpu 2,3 \
                --opt diffgrad
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25.6 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ---------------------------------------------------------
# 25.6 M    Trainable params
# 0         Non-trainable params
# 25.6 M    Total params
# 102.305   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# {'avg_val_loss': 9.304319381713867, 'avg_acc': 0.0}
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 3.515345335006714, 'avg_acc': 0.2107113152742386}
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 3.0474863052368164, 'avg_acc': 0.2564167082309723}
# Validating: 0it [00:00, ?it/s]
# ...

# %% [markdown]
# ## AdaMod

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 1e-2 --gpu 2,3 \
                --opt adamod
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25.6 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ---------------------------------------------------------
# 25.6 M    Trainable params
# 0         Non-trainable params
# 25.6 M    Total params
# 102.305   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# {'avg_val_loss': 9.283401489257812, 'avg_acc': 0.0}
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 2.948855400085449, 'avg_acc': 0.28026777505874634}
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 2.8337879180908203, 'avg_acc': 0.3020898103713989}
# Validating: 0it [00:00, ?it/s]
# ...

# %% [markdown]
# ## Madam

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 1e-2 --gpu 2,3 \
                --opt madam --sched_type flat_and_anneal --ann_start 0.5
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25.6 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ---------------------------------------------------------
# 25.6 M    Trainable params
# 0         Non-trainable params
# 25.6 M    Total params
# 102.305   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# {'avg_val_loss': 7.992323875427246, 'avg_acc': 0.0}
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 2.9115185737609863, 'avg_acc': 0.30466166138648987}
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 2.870323657989502, 'avg_acc': 0.3055534064769745}
# Validating: 0it [00:00, ?it/s]
# ...

# %% [markdown]
# ## Apollo

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 3e-3 --gpu 2,3 \
                --opt apollo
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/over9000/train.py in <module>
#     155
#     156 @call_parse
# --> 157 def main(
#     158         run: Param("Number of run", int)=20,
#     159         gpu:Param("GPU to run on", str)=None,
#
# ~/.anaconda/envs/over9000/lib/python3.9/site-packages/fastcore/script.py in call_parse(func)
#     108         setattr(mod, func.__name__, _f)
#     109         SCRIPT_INFO.func = func.__name__
# --> 110         return _f()
#     111     else: return _f
#
# ~/.anaconda/envs/over9000/lib/python3.9/site-packages/fastcore/script.py in _f(*args, **kwargs)
#     103         xtra = otherwise(args.pop('xtra', ''), eq(1), p.prog)
# ...

# %% [markdown]
# ## AdaBelief

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 3e-3 --gpu 2,3 \
                --opt adabelief --eps 1e-16
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25.6 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ---------------------------------------------------------
# 25.6 M    Trainable params
# 0         Non-trainable params
# 25.6 M    Total params
# 102.305   Total estimated model params size (MB)
# Please check your arguments if you have upgraded adabelief-pytorch from version 0.0.5.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  ---------
# adabelief-pytorch=0.0.5  1e-08  False              False
# Current version (0.1.0)  1e-16  True               True
# ...

# %% [markdown]
# ## MADGRAD

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --epoch 5 --lr 1e-3 --gpu 2,3 --opt madgrad
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name      | Type                       | Params
# ---------------------------------------------------------
# 0 | model     | XResNet                    | 25.6 M
# 1 | loss_func | LabelSmoothingCrossEntropy | 0
# ---------------------------------------------------------
# 25.6 M    Trainable params
# 0         Non-trainable params
# 25.6 M    Total params
# 102.305   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# {'avg_val_loss': 10.520833969116211, 'avg_acc': 0.0}
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 3.48728084564209, 'avg_acc': 0.1936388611793518}
# Validating: 0it [00:00, ?it/s]
# {'avg_val_loss': 2.835530996322632, 'avg_acc': 0.29514965415000916}
# Validating: 0it [00:00, ?it/s]
# ...
