# %% [markdown]
# ## Baseline: Adam + OneCycle

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 3e-3 --gpu 0 \
                --opt adam
# Out:
# To use this log_lamb_rs, please run 'pip install tensorboardx'. Also you must have Tensorboard running to see results
# lr: 0.003; eff_lr: 0.003; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /home/u/.fastai/data/imagewoof2-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.208480</td>
#       <td>2.645737</td>
#       <td>0.199287</td>
#       <td>0.693561</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.023464</td>
#       <td>2.090284</td>
#       <td>0.375159</td>
#       <td>0.859506</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.845214</td>
#       <td>1.861119</td>
#       <td>0.382286</td>
#       <td>0.858997</td>
# ...

# %% [markdown]
# ## RangerLars (RAdam + LARS + Lookahead) + flat_and_anneal

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 0 \
                --opt over9000 --sched_type flat_and_anneal --ann_start 0.5
# Out:
# lr: 0.01; eff_lr: 0.01; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /home/u/.fastai/data/imagewoof2-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.249803</td>
#       <td>2.399703</td>
#       <td>0.272843</td>
#       <td>0.733774</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.019560</td>
#       <td>1.877007</td>
#       <td>0.385594</td>
#       <td>0.874268</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.809442</td>
#       <td>1.990171</td>
#       <td>0.340290</td>
#       <td>0.840926</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.622866</td>
#       <td>1.506991</td>
# ...

# %% [markdown]
# ## Ralamb (RAdam + LARS)

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 3e-3 --gpu 0 \
                --opt ralamb --sched_type flat_and_anneal --ann_start 0.5
# Out:
# lr: 0.003; eff_lr: 0.003; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /home/u/.fastai/data/imagewoof2-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.212010</td>
#       <td>2.639984</td>
#       <td>0.238992</td>
#       <td>0.745737</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.074849</td>
#       <td>2.030808</td>
#       <td>0.363197</td>
#       <td>0.818529</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.874405</td>
#       <td>1.982288</td>
#       <td>0.339272</td>
#       <td>0.860015</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.667360</td>
#       <td>1.606130</td>
# ...

# %% [markdown]
# ## Ranger (RAdam + Lookahead)

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 0 \
                --opt ranger --sched_type flat_and_anneal --ann_start 0.5
# Out:
# lr: 0.01; eff_lr: 0.01; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /home/u/.fastai/data/imagewoof2-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.236296</td>
#       <td>3.632135</td>
#       <td>0.221176</td>
#       <td>0.683380</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.014677</td>
#       <td>1.896545</td>
#       <td>0.382540</td>
#       <td>0.851107</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.885021</td>
#       <td>2.235722</td>
#       <td>0.305421</td>
#       <td>0.806058</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.700021</td>
#       <td>1.632104</td>
# ...

# %% [markdown]
# ## Novograd + bigger lr

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 3e-2 --gpu 0 \
                --opt novograd --sched_type flat_and_anneal --ann_start 0.5
# Out:
# lr: 0.03; eff_lr: 0.03; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /home/u/.fastai/data/imagewoof2-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.210208</td>
#       <td>2.326662</td>
#       <td>0.225248</td>
#       <td>0.691779</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.982233</td>
#       <td>2.455249</td>
#       <td>0.237465</td>
#       <td>0.810384</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.823365</td>
#       <td>2.022797</td>
#       <td>0.371087</td>
#       <td>0.821583</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.666791</td>
#       <td>1.744594</td>
# ...

# %% [markdown]
# ## Radam

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 0 \
                --opt radam --sched_type flat_and_anneal --ann_start 0.5
# Out:
# lr: 0.01; eff_lr: 0.01; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /home/u/.fastai/data/imagewoof2-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.278423</td>
#       <td>2.286262</td>
#       <td>0.180708</td>
#       <td>0.667854</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.093412</td>
#       <td>2.521431</td>
#       <td>0.188343</td>
#       <td>0.717485</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.969934</td>
#       <td>2.262959</td>
#       <td>0.260372</td>
#       <td>0.776279</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.821614</td>
#       <td>1.791243</td>
# ...

# %% [markdown]
# ## Lookahead

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 3e-3 --gpu 0 \
                --opt lookahead
# Out:
# lr: 0.003; eff_lr: 0.003; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /home/u/.fastai/data/imagewoof2-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.155937</td>
#       <td>3.118428</td>
#       <td>0.206668</td>
#       <td>0.658183</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.024756</td>
#       <td>1.872954</td>
#       <td>0.407483</td>
#       <td>0.875032</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.820788</td>
#       <td>2.138430</td>
#       <td>0.346399</td>
#       <td>0.835582</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.608730</td>
#       <td>1.580748</td>
# ...

# %% [markdown]
# ## Lamb

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 0 \
                --opt lamb
# Out:
# lr: 0.01; eff_lr: 0.01; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /home/u/.fastai/data/imagewoof2-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.173986</td>
#       <td>2.914467</td>
#       <td>0.150165</td>
#       <td>0.634004</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.101562</td>
#       <td>2.208541</td>
#       <td>0.286078</td>
#       <td>0.779842</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.923764</td>
#       <td>2.069391</td>
#       <td>0.315602</td>
#       <td>0.835073</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.768258</td>
#       <td>1.682156</td>
# ...

# %% [markdown]
# ## DiffGrad

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 0 \
                --opt diffgrad
# Out:
# lr: 0.01; eff_lr: 0.01; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /home/u/.fastai/data/imagewoof2-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.230776</td>
#       <td>2.234019</td>
#       <td>0.237974</td>
#       <td>0.761262</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.091937</td>
#       <td>2.178482</td>
#       <td>0.262153</td>
#       <td>0.712141</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.886271</td>
#       <td>1.876546</td>
#       <td>0.368542</td>
#       <td>0.873250</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.707363</td>
#       <td>1.665123</td>
# ...

# %% [markdown]
# ## AdaMod

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 0 \
                --opt adamod
# Out:
# lr: 0.01; eff_lr: 0.01; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /home/u/.fastai/data/imagewoof2-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.157784</td>
#       <td>2.310877</td>
#       <td>0.232629</td>
#       <td>0.734793</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.135285</td>
#       <td>2.470161</td>
#       <td>0.251209</td>
#       <td>0.696615</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.956260</td>
#       <td>2.098777</td>
#       <td>0.287859</td>
#       <td>0.792568</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.833946</td>
#       <td>1.999061</td>
# ...

# %% [markdown]
# ## Madam

# %%
# %run train.py --run 20 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 1e-2 --gpu 0 \
                --opt madam --sched_type flat_and_anneal --ann_start 0.5
# Out:
# lr: 0.01; eff_lr: 0.01; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /home/u/.fastai/data/imagewoof2-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.082120</td>
#       <td>2.062827</td>
#       <td>0.293968</td>
#       <td>0.810130</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.908810</td>
#       <td>2.202995</td>
#       <td>0.267244</td>
#       <td>0.778061</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.820215</td>
#       <td>2.124503</td>
#       <td>0.300076</td>
#       <td>0.797149</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.696054</td>
#       <td>1.744791</td>
# ...
